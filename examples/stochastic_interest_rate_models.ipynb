# %% [markdown]
# <a href="https://colab.research.google.com/github/PiotMik/quantutils/blob/feature%2Fexample_interest_rates/examples/stochastic_interest_rate_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/PiotMik/quantutils.git
# Out:
# ...
#   Cloning https://github.com/PiotMik/quantutils.git (to revision milstein) to c:\users\wmsl\appdata\local\temp\pip-req-build-0if451ez
#   Running command git clone -q https://github.com/PiotMik/quantutils.git 'C:\Users\wmsl\AppData\Local\Temp\pip-req-build-0if451ez'
#   WARNING: Did not find branch or tag 'milstein', assuming revision or ref.
#   Running command git checkout -q milstein
#   error: pathspec 'milstein' did not match any file(s) known to git
# WARNING: Discarding git+https://github.com/PiotMik/quantutils.git@milstein. Command errored out with exit status 1: git checkout -q milstein Check the logs for full command output.
# ERROR: Command errored out with exit status 1: git checkout -q milstein Check the logs for full command output.

# %%
from quantutils.models.interest_rates import merton, vasicek
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("seaborn")
plt.rcParams['figure.figsize'] = (10, 5)

# %% [markdown]
# ## SDE simulation

# %%
n_steps = 10000
t, xt = merton(mu = 0.05,
               sigma = 0.3,
               x0 = 0.01,
               n_steps= n_steps,
               dt= 1.0/n_steps)
plt.plot(t, xt)
plt.xlabel("t")
plt.ylabel("IR")
_ = plt.title("Interest Rate simulation - Merton model ")

# %%
t, xt = vasicek(a = 0.7,
                b = 1.0,
                sigma = 0.04,
                x0 = 0.3,
                n_steps=20000,
                dt=0.001)
plt.plot(t, xt)
plt.xlabel("t")
plt.ylabel("IR")
_ = plt.title("Interest Rate simulation - Vasicek model")
